# %% [markdown]
# ## Procesamiento de Lenguaje Natural
# ## Práctica 4: DOR (Este notebook esta COMPLETO por lo que no tienes que subirlo)

# %% [markdown]
# ### Lectura simple de datos

# %%
import os
import re
from keras.preprocessing.text import Tokenizer
def get_texts_from_file(path_corpus, path_truth):
    tr_txt = []
    tr_y = []
    with open(path_corpus, "r") as f_corpus, open(path_truth, "r") as f_truth:
        for twitt in f_corpus:
            tr_txt += [twitt]
        for label in f_truth:
            tr_y += [label]        
    return tr_txt, tr_y
# Out:
# Using TensorFlow backend.

# %%
tr_txt, tr_y = get_texts_from_file("./mex_train.txt", "./mex_train_labels.txt")

# %% [markdown]
# ### Estadisticas Simples

# %%
tr_y = list(map(int, tr_y))

# %%
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

print(Counter(tr_y))
plt.hist(tr_y, bins=len(set(tr_y)))
plt.ylabel('Users');
plt.xlabel('Class');
# Out:
# Counter({0: 3563, 1: 1981})

# %% [markdown]
# # Un ojo a los datos

# %%
tr_txt[:10]
# Out:
# ['lo peor de todo es que no me dan por un tiempo y luego vuelven estoy hasta la verga de estl\n',
#  'a la vga no seas mamón 45 putos minutos después me dices que apenas sales no me querías avisar en 3 horas? 😑\n',
#  'considero que lo más conveniente seria que lo retes a unos vergazos mi jelipe! rómpele la madre a ese pinchi joto!\n',
#  'el marica de mi ex me tiene bloqueada de todo así  uno no puede admirar la "belleza" de su garnacha 😂\n',
#  'mujer despechadaya pinche amlo hazle esta que se pela la loca #reynosafollow #reynosa\n',
#  'putos. no tienen madre. ambriados mantenidos. ojetes. como es posible. mejor matarlos\n',
#  'ustedes si puden andar de chanceros pero cuidadito y seamos nosotras porque luego luego empiezan a mamar hijos de la chingada.\n',
#  '@usuario jajjaja te digo esa madre si está buena ajjaja\n',
#  'odio los putos trámites de titulación 😡😡😡😡😡😡😡😡😡😡😡 pero me urge la precedula.\n',
#  '@usuario no te equivocabas mi madre y tu tenían muchísima razón siempre es mejor lo que viene 💚\n']

# %% [markdown]
# ### Construcción simple del vocabulario

# %%
import nltk

# %%
corpus_palabras = []
for doc in tr_txt:
    corpus_palabras += doc.split()
#print(corpus_palabras)
fdist = nltk.FreqDist(corpus_palabras)

# %%
fdist
# Out:
# FreqDist({'de': 3342, 'que': 3336, 'a': 2605, 'la': 2417, 'y': 2225, 'no': 1743, 'me': 1582, 'el': 1285, '@usuario': 1243, 'en': 1184, ...})

# %%
len(fdist)
# Out:
# 17055

# %%
def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

# %%
V = sortFreqDict(fdist)
V = V[:5000]

# %%
dict_indices = dict()
cont = 0
for weight, word in V:
    dict_indices[word] = cont
    cont += 1

# %% [markdown]
# ### Bolsa de Términos

# %%
import numpy as np
def build_bow_tr(tr_txt, V, dict_indices):
    BOW = np.zeros((len(tr_txt),len(V)), dtype=int)
    cont_doc = 0
    for tr in tr_txt:
        fdist_doc = nltk.FreqDist(tr.split())
        for word in fdist_doc:
            if word in dict_indices:
                BOW[cont_doc, dict_indices[word]] = fdist_doc[word]
        cont_doc += 1       
    return BOW

# %% [markdown]
# ### Debug?

# %%
tr_txt[10]
# Out:
# '"no me importa lo que digan esos putos periodistas la puta que los pario oh oh oh hay que alentar a la selección"\n'

# %%
fdist_doc = nltk.FreqDist(tr_txt[10].split())

# %%
fdist_doc
# Out:
# FreqDist({'que': 3, 'oh': 3, 'la': 2, '"no': 1, 'me': 1, 'importa': 1, 'lo': 1, 'digan': 1, 'esos': 1, 'putos': 1, ...})

# %% [markdown]
# ### Bolsa de Terminos en Validación

# %%
BOW_tr=build_bow_tr(tr_txt, V, dict_indices)

# %%
print(V[:10])
# Out:
# [(3342, 'de'), (3336, 'que'), (2605, 'a'), (2417, 'la'), (2225, 'y'), (1743, 'no'), (1582, 'me'), (1285, 'el'), (1243, '@usuario'), (1184, 'en')]

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
#print(BOW[10])

# %%
val_txt, val_y = get_texts_from_file("./mex_val.txt", "./mex_val_labels.txt")

# %%
val_y = list(map(int, val_y))

# %%
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

print(Counter(val_y))
plt.hist(val_y, bins=len(set(val_y)))
plt.ylabel('Users');
plt.xlabel('Class');
# Out:
# Counter({0: 397, 1: 219})

# %%
val_txt[:10]
# Out:
# ['así debería ser siempre para que se mueran a la verga\n',
#  'cada día me siento como un perro ovejero tratando de cuidar sus ovejas vale madre pinches rateros póngase a trabajar.😤\n',
#  'hijo de tu puta madre nadamas te la pasas mamando pinche wilo de closet\n',
#  'soñé horrible espero no se cumpla putos temblores.\n',
#  '@usuario mejor vas y la chingas tú veo tus publicaciones y solo denotan inconformidad como típico ciudadano quejumbroso que no hace nada por cambiar\n',
#  'y quizás este loca y quizás me guste estarlo... #siempreneruda\n',
#  'me tienen hasta la verga con sus putos #boomerang pendejos y sin sentido.\n',
#  'cuando va a ser el día que encuentre a alguien en quien pueda  confiar posts la re puta madre?\n',
#  '#ahoritaestoypensando  como putas puede pasar esto?\n',
#  '#todoibabienpero valio madre ya me atacó el insomnio🙅\n']

# %%
BOW_val=build_bow_tr(val_txt, V, dict_indices)

# %%
import math
from sklearn.model_selection import train_test_split

def compute_dor(TR, ndocs_out=0, y=None):    
    TR_subset_in = None
    if y is None:
        TR_subset_in, TR_subset_out = train_test_split(TR, test_size=ndocs_out, random_state=1)
    else :
        TR_subset_in, TR_subset_out = train_test_split(TR, stratify=y, test_size=ndocs_out, random_state=1)
    
    DTR = np.zeros((TR_subset_in.shape[1], TR_subset_in.shape[0]), dtype=np.float)
    print("DOR: Shape of the input matrix (BoT):", TR.shape)
    print("DOR: Shape of the term-feat matrix:", DTR.shape)

    tam_V = TR_subset_in.shape[1]
    for doc, i in zip(TR_subset_in, range(len(TR_subset_in))):
        nonzero_positions = np.nonzero(doc)[0] # returns a tuple of n-dimensions. Since we have 1D array docs, it returns a tuple with one element. thus, we get the 0 index.
        tam_v = len(nonzero_positions) 
        for term in nonzero_positions:
            DTR[term, i] = (1 + math.log10(doc[term])) * math.log10(tam_V/tam_v)
    return DTR

# %%
from sklearn import preprocessing
DOR_base = compute_dor(BOW_tr, 0.01)
DOR_base = preprocessing.normalize(DOR_base, norm='l2')
# Out:
# DOR: Shape of the input matrix (BoT): (5544, 5000)
# DOR: Shape of the term-feat matrix: (5000, 5488)

# %%
from sklearn.feature_selection import SelectKBest, chi2
feats = SelectKBest(chi2, k=1000)
feats.fit(BOW_tr, tr_y)
# Out:
# SelectKBest(k=1000, score_func=<function chi2 at 0x7f4ea9842170>)

# %%
best=feats.get_support(indices=True)

# %%
dict_indice_invertido = {}
for w in dict_indices:
    dict_indice_invertido[dict_indices[w]] = w

# %%
target_words = [dict_indice_invertido[index] for index in best]
words = [word for word in target_words if word in dict_indices] 
target_matrix = np.array([DOR_base[dict_indices[word]] for word in words])

# %%
target_matrix.shape
# Out:
# (1000, 5488)

# %%
from tsne import tsne
reduced_matrix = tsne(target_matrix, 2);
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 1000...
# Computing P-values for point 500 of 1000...
# Mean value of sigma: 0.096264
# Iteration 10: error is 17.406154
# Iteration 20: error is 17.063509
# Iteration 30: error is 16.860784
# Iteration 40: error is 16.894361
# Iteration 50: error is 16.868429
# Iteration 60: error is 16.877822
# Iteration 70: error is 16.862005
# Iteration 80: error is 16.856299
# Iteration 90: error is 16.882728
# Iteration 100: error is 16.862300
# Iteration 110: error is 1.975970
# Iteration 120: error is 1.475971
# Iteration 130: error is 1.285498
# Iteration 140: error is 1.178877
# Iteration 150: error is 1.110237
# Iteration 160: error is 1.063228
# Iteration 170: error is 1.028975
# Iteration 180: error is 1.002430
# Iteration 190: error is 0.981570
# Iteration 200: error is 0.964918
# Iteration 210: error is 0.950962
# Iteration 220: error is 0.939592
# Iteration 230: error is 0.930232
# Iteration 240: error is 0.922311
# Iteration 250: error is 0.915614
# Iteration 260: error is 0.909856
# Iteration 270: error is 0.904955
# Iteration 280: error is 0.900646
# Iteration 290: error is 0.896816
# Iteration 300: error is 0.893445
# Iteration 310: error is 0.890443
# Iteration 320: error is 0.887793
# Iteration 330: error is 0.885431
# Iteration 340: error is 0.883270
# Iteration 350: error is 0.881269
# Iteration 360: error is 0.879516
# Iteration 370: error is 0.877995
# Iteration 380: error is 0.876660
# Iteration 390: error is 0.875457
# Iteration 400: error is 0.874358
# Iteration 410: error is 0.873343
# Iteration 420: error is 0.872399
# Iteration 430: error is 0.871534
# Iteration 440: error is 0.870747
# Iteration 450: error is 0.870016
# Iteration 460: error is 0.869340
# Iteration 470: error is 0.868719
# Iteration 480: error is 0.868148
# Iteration 490: error is 0.867616
# Iteration 500: error is 0.867118
# Iteration 510: error is 0.866652
# Iteration 520: error is 0.866220
# Iteration 530: error is 0.865813
# Iteration 540: error is 0.865413
# Iteration 550: error is 0.865020
# Iteration 560: error is 0.864652
# Iteration 570: error is 0.864319
# Iteration 580: error is 0.864022
# Iteration 590: error is 0.863749
# Iteration 600: error is 0.863490
# Iteration 610: error is 0.863244
# Iteration 620: error is 0.863027
# Iteration 630: error is 0.862824
# Iteration 640: error is 0.862632
# Iteration 650: error is 0.862449
# Iteration 660: error is 0.862273
# Iteration 670: error is 0.862107
# Iteration 680: error is 0.861950
# Iteration 690: error is 0.861803
# Iteration 700: error is 0.861662
# Iteration 710: error is 0.861529
# Iteration 720: error is 0.861400
# Iteration 730: error is 0.861274
# Iteration 740: error is 0.861146
# Iteration 750: error is 0.860976
# Iteration 760: error is 0.860774
# Iteration 770: error is 0.860606
# Iteration 780: error is 0.860485
# Iteration 790: error is 0.860375
# Iteration 800: error is 0.860272
# Iteration 810: error is 0.860174
# Iteration 820: error is 0.860080
# Iteration 830: error is 0.859990
# Iteration 840: error is 0.859905
# Iteration 850: error is 0.859825
# Iteration 860: error is 0.859750
# Iteration 870: error is 0.859677
# Iteration 880: error is 0.859605
# Iteration 890: error is 0.859537
# Iteration 900: error is 0.859470
# Iteration 910: error is 0.859403
# Iteration 920: error is 0.859338
# Iteration 930: error is 0.859276
# Iteration 940: error is 0.859215
# Iteration 950: error is 0.859153
# Iteration 960: error is 0.859092
# Iteration 970: error is 0.859029
# Iteration 980: error is 0.858964
# Iteration 990: error is 0.858900
# Iteration 1000: error is 0.858836

# %%
max_x = np.amax(reduced_matrix, axis=0)[0]
max_y = np.amax(reduced_matrix, axis=0)[1]

# %%
plt.figure(figsize=(40, 40), dpi=100); plt.xlim((-max_x,max_x)); plt.ylim((-max_y,max_y))
plt.scatter(reduced_matrix[:, 0], reduced_matrix[:, 1], 20);
for idx, word in enumerate(words[:]):
    x = reduced_matrix[idx, 0]
    y = reduced_matrix[idx, 1]
    plt.annotate(word, (x,y))
# Out:
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 129300 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129318 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129318 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128405 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127996 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128405 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127996 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 128000 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129300 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127814 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127814 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127926 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127926 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/aplm/anaconda3/envs/nlp/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127473 missing from current font.
#   font.set_text(s, 0, flags=flags)
